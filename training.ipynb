# %% [markdown]
# ### Fine-Tuning VGG19 and YOLOv5s
# This notebook trains and evaluates the VGG19 and YOLOv5 models.
# It is designed to run on Google Colab so a GPU can be used (can be selected by configuring the run time type). The notebook connects to Google drive, takes the data from drive, clones the git repository and then evaluates the models. Finally, it saves the results on drive.

# %%
# !nvidia-smi
# Out:
# Sun Feb  1 17:16:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Clone git repo:

# %%
# %cd /content
# !git clone https://github.com/asher-stav/ml_assignment_4.git

# %cd ml_assignment_4
# Out:
# /content
# Cloning into 'ml_assignment_4'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 110 (delta 55), reused 83 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (110/110), 19.73 KiB | 3.95 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/ml_assignment_4

# %%
# !pwd
# Out:
# /content/ml_assignment_4

# %% [markdown]
# Copy dataset from Google drive:

# %%
# !cp -r '<path-to-data-on-drive>' .

# %% [markdown]
# **Run Training of Models:**

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.24.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Collecting ultralytics (from -r requirements.txt (line 8))
#   Downloading ultralytics-8.4.9-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (3.1.46)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (75.2.0)
# Collecting urllib3>=2.6.0 (from -r requirements.txt (line 11))
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 6)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 8)) (4.13.0.90)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 8)) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics->-r requirements.txt (line 8))
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 9)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 9)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 8)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 8)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 8)) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (3.0.3)
# Downloading ultralytics-8.4.9-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.5 MB/s eta 0:00:00
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 12.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: urllib3, ultralytics-thop, ultralytics
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# Successfully installed ultralytics-8.4.9 ultralytics-thop-2.0.18 urllib3-2.6.3

# %%
# !python main.py
# Out:
# Converting labels to CSV format...
# dict_keys(['__header__', '__version__', '__globals__', 'labels'])
# CSV saved: data/imagelabels.csv
#
# Extracting images...
#
# Splitting data to train-validation-test...
# [2026-02-01 17:17:17] [evaluate_vgg19]
# --------  Evaluating VGG19 --------
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:03<00:00, 168MB/s]
# [2026-02-01 17:17:22] [build_vgg19] VGG19 Last layer replaced with:           Linear
# [2026-02-01 17:17:22] [build_vgg19]       Number of in features (last layer): 4096
# [2026-02-01 17:17:22] [build_vgg19]       Number of classes:                  102
# [2026-02-01 17:17:22] [criterion_factory] Using criterion: CrossEntropyLoss
# [2026-02-01 17:17:22] [evaluate_model] Created DataLoaders
# [2026-02-01 17:17:22] [optimizer_factory] Using optimizer: Adam
# [2026-02-01 17:17:22] [evaluate_model] Training...
# [2026-02-01 17:17:22] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:17:22] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:17:22] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:17:22] [train_epoch] Using device: cuda
# [2026-02-01 17:18:15] [train_epoch] Epoch Loss: 3.1690 | Epoch Acc: 0.3190
# [2026-02-01 17:18:15] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:18:15] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:18:15] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:18:15] [validate] Using device: cuda
# [2026-02-01 17:18:40] [validate] Validation Loss: 2.1029 | Validation Acc: 0.6234
# [2026-02-01 17:18:40] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:18:40] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:18:40] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:18:40] [test_model] Using device: cuda
# [2026-02-01 17:19:06] [test_model] Test Loss: 2.1233 | Test Acc: 0.6147
# [2026-02-01 17:19:06] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:19:06] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:19:06] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:19:06] [train_epoch] Using device: cuda
# [2026-02-01 17:19:57] [train_epoch] Epoch Loss: 1.6537 | Epoch Acc: 0.6600
# [2026-02-01 17:19:57] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:19:57] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:19:57] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:19:57] [validate] Using device: cuda
# [2026-02-01 17:20:22] [validate] Validation Loss: 1.5218 | Validation Acc: 0.7162
# [2026-02-01 17:20:22] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:20:22] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:20:22] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:20:22] [test_model] Using device: cuda
# [2026-02-01 17:20:47] [test_model] Test Loss: 1.5364 | Test Acc: 0.7051
# [2026-02-01 17:20:47] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:20:47] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:20:47] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:20:47] [train_epoch] Using device: cuda
# [2026-02-01 17:21:37] [train_epoch] Epoch Loss: 1.2138 | Epoch Acc: 0.7396
# [2026-02-01 17:21:37] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:21:37] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:21:37] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:21:37] [validate] Using device: cuda
# [2026-02-01 17:22:02] [validate] Validation Loss: 1.2729 | Validation Acc: 0.7445
# [2026-02-01 17:22:02] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:22:02] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:22:02] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:22:02] [test_model] Using device: cuda
# [2026-02-01 17:22:27] [test_model] Test Loss: 1.2918 | Test Acc: 0.7314
# [2026-02-01 17:22:27] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:22:27] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:22:27] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:22:27] [train_epoch] Using device: cuda
# [2026-02-01 17:23:17] [train_epoch] Epoch Loss: 1.0006 | Epoch Acc: 0.7829
# [2026-02-01 17:23:17] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:23:17] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:23:17] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:23:17] [validate] Using device: cuda
# [2026-02-01 17:23:42] [validate] Validation Loss: 1.1359 | Validation Acc: 0.7665
# [2026-02-01 17:23:42] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:23:42] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:23:42] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:23:42] [test_model] Using device: cuda
# [2026-02-01 17:24:07] [test_model] Test Loss: 1.1532 | Test Acc: 0.7554
# [2026-02-01 17:24:07] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:24:07] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:24:07] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:24:07] [train_epoch] Using device: cuda
# [2026-02-01 17:24:57] [train_epoch] Epoch Loss: 0.8723 | Epoch Acc: 0.8083
# [2026-02-01 17:24:57] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:24:57] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:24:57] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:24:57] [validate] Using device: cuda
# [2026-02-01 17:25:22] [validate] Validation Loss: 1.0388 | Validation Acc: 0.7758
# [2026-02-01 17:25:22] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:25:22] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:25:22] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:25:22] [test_model] Using device: cuda
# [2026-02-01 17:25:47] [test_model] Test Loss: 1.0595 | Test Acc: 0.7573
# [2026-02-01 17:25:47] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:25:47] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:25:47] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:25:47] [train_epoch] Using device: cuda
# [2026-02-01 17:26:36] [train_epoch] Epoch Loss: 0.7649 | Epoch Acc: 0.8337
# [2026-02-01 17:26:36] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:26:36] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:26:36] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:26:36] [validate] Using device: cuda
# [2026-02-01 17:27:01] [validate] Validation Loss: 0.9643 | Validation Acc: 0.7811
# [2026-02-01 17:27:01] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:27:01] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:27:01] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:27:01] [test_model] Using device: cuda
# [2026-02-01 17:27:26] [test_model] Test Loss: 0.9856 | Test Acc: 0.7715
# [2026-02-01 17:27:26] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:27:26] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:27:26] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:27:26] [train_epoch] Using device: cuda
# [2026-02-01 17:28:16] [train_epoch] Epoch Loss: 0.6928 | Epoch Acc: 0.8500
# [2026-02-01 17:28:16] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:28:16] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:28:16] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:28:16] [validate] Using device: cuda
# [2026-02-01 17:28:41] [validate] Validation Loss: 0.9212 | Validation Acc: 0.7875
# [2026-02-01 17:28:41] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:28:41] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:28:41] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:28:41] [test_model] Using device: cuda
# [2026-02-01 17:29:06] [test_model] Test Loss: 0.9439 | Test Acc: 0.7744
# [2026-02-01 17:29:06] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:29:06] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:29:06] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:29:06] [train_epoch] Using device: cuda
# [2026-02-01 17:29:56] [train_epoch] Epoch Loss: 0.6360 | Epoch Acc: 0.8532
# [2026-02-01 17:29:56] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:29:56] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:29:56] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:29:56] [validate] Using device: cuda
# [2026-02-01 17:30:21] [validate] Validation Loss: 0.8745 | Validation Acc: 0.8012
# [2026-02-01 17:30:21] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:30:21] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:30:21] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:30:21] [test_model] Using device: cuda
# [2026-02-01 17:30:46] [test_model] Test Loss: 0.8955 | Test Acc: 0.7847
# [2026-02-01 17:30:46] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:30:46] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:30:46] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:30:46] [train_epoch] Using device: cuda
# [2026-02-01 17:31:36] [train_epoch] Epoch Loss: 0.5791 | Epoch Acc: 0.8710
# [2026-02-01 17:31:36] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:31:36] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:31:36] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:31:36] [validate] Using device: cuda
# [2026-02-01 17:32:01] [validate] Validation Loss: 0.8508 | Validation Acc: 0.7948
# [2026-02-01 17:32:01] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:32:01] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:32:01] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:32:01] [test_model] Using device: cuda
# [2026-02-01 17:32:27] [test_model] Test Loss: 0.8648 | Test Acc: 0.7905
# [2026-02-01 17:32:27] [train_epoch] Starting train on Model:     VGG,
# [2026-02-01 17:32:27] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:32:27] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:32:27] [train_epoch] Using device: cuda
# [2026-02-01 17:33:16] [train_epoch] Epoch Loss: 0.5494 | Epoch Acc: 0.8784
# [2026-02-01 17:33:16] [validate] Starting validate on Model:     VGG,
# [2026-02-01 17:33:16] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:33:16] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:33:16] [validate] Using device: cuda
# [2026-02-01 17:33:41] [validate] Validation Loss: 0.8206 | Validation Acc: 0.7987
# [2026-02-01 17:33:41] [test_model] Starting test on Model:     VGG,
# [2026-02-01 17:33:41] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:33:41] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:33:41] [test_model] Using device: cuda
# [2026-02-01 17:34:06] [test_model] Test Loss: 0.8359 | Test Acc: 0.7969
# [2026-02-01 17:34:06] [evaluate_yolov5] -------- Evaluating YOLOv5 --------
# /usr/local/lib/python3.12/dist-packages/torch/hub.py:335: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv5 🚀 2026-2-1 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 169MB/s]
#
# [2026-02-01 17:34:11] [build_yolo_v5] YOLOv5 created with 102 Classes
# [2026-02-01 17:34:11] [criterion_factory] Using criterion: CrossEntropyLoss
# [2026-02-01 17:34:11] [evaluate_model] Created DataLoaders
# [2026-02-01 17:34:11] [optimizer_factory] Using optimizer: Adam
# [2026-02-01 17:34:11] [evaluate_model] Training...
# [2026-02-01 17:34:11] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:34:11] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:34:11] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:34:11] [train_epoch] Using device: cuda
# [2026-02-01 17:35:49] [train_epoch] Epoch Loss: 4.3674 | Epoch Acc: 0.0647
# [2026-02-01 17:35:49] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:35:49] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:35:49] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:35:49] [validate] Using device: cuda
# [2026-02-01 17:36:39] [validate] Validation Loss: 4.0904 | Validation Acc: 0.1085
# [2026-02-01 17:36:39] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:36:39] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:36:39] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:36:39] [test_model] Using device: cuda
# [2026-02-01 17:37:28] [test_model] Test Loss: 4.0897 | Test Acc: 0.1118
# [2026-02-01 17:37:28] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:37:28] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:37:28] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:37:28] [train_epoch] Using device: cuda
# [2026-02-01 17:39:07] [train_epoch] Epoch Loss: 3.9181 | Epoch Acc: 0.1522
# [2026-02-01 17:39:07] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:39:07] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:39:07] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:39:07] [validate] Using device: cuda
# [2026-02-01 17:39:57] [validate] Validation Loss: 3.7460 | Validation Acc: 0.1969
# [2026-02-01 17:39:57] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:39:57] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:39:57] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:39:57] [test_model] Using device: cuda
# [2026-02-01 17:40:47] [test_model] Test Loss: 3.7456 | Test Acc: 0.1909
# [2026-02-01 17:40:47] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:40:47] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:40:47] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:40:47] [train_epoch] Using device: cuda
# [2026-02-01 17:42:24] [train_epoch] Epoch Loss: 3.5977 | Epoch Acc: 0.2335
# [2026-02-01 17:42:24] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:42:24] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:42:24] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:42:24] [validate] Using device: cuda
# [2026-02-01 17:43:13] [validate] Validation Loss: 3.4897 | Validation Acc: 0.2487
# [2026-02-01 17:43:13] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:43:13] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:43:13] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:43:13] [test_model] Using device: cuda
# [2026-02-01 17:44:02] [test_model] Test Loss: 3.4906 | Test Acc: 0.2402
# [2026-02-01 17:44:02] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:44:02] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:44:02] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:44:02] [train_epoch] Using device: cuda
# [2026-02-01 17:45:40] [train_epoch] Epoch Loss: 3.3516 | Epoch Acc: 0.2811
# [2026-02-01 17:45:40] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:45:40] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:45:40] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:45:40] [validate] Using device: cuda
# [2026-02-01 17:46:29] [validate] Validation Loss: 3.2867 | Validation Acc: 0.2775
# [2026-02-01 17:46:29] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:46:29] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:46:29] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:46:29] [test_model] Using device: cuda
# [2026-02-01 17:47:17] [test_model] Test Loss: 3.2888 | Test Acc: 0.2793
# [2026-02-01 17:47:17] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:47:17] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:47:17] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:47:17] [train_epoch] Using device: cuda
# [2026-02-01 17:48:57] [train_epoch] Epoch Loss: 3.1472 | Epoch Acc: 0.3180
# [2026-02-01 17:48:57] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:48:57] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:48:57] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:48:57] [validate] Using device: cuda
# [2026-02-01 17:49:46] [validate] Validation Loss: 3.1267 | Validation Acc: 0.3307
# [2026-02-01 17:49:46] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:49:46] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:49:46] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:49:46] [test_model] Using device: cuda
# [2026-02-01 17:50:35] [test_model] Test Loss: 3.1294 | Test Acc: 0.3291
# [2026-02-01 17:50:35] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:50:35] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:50:35] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:50:35] [train_epoch] Using device: cuda
# [2026-02-01 17:52:13] [train_epoch] Epoch Loss: 2.9851 | Epoch Acc: 0.3588
# [2026-02-01 17:52:13] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:52:13] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:52:13] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:52:13] [validate] Using device: cuda
# [2026-02-01 17:53:01] [validate] Validation Loss: 2.9825 | Validation Acc: 0.3478
# [2026-02-01 17:53:01] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:53:01] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:53:01] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:53:01] [test_model] Using device: cuda
# [2026-02-01 17:53:50] [test_model] Test Loss: 2.9884 | Test Acc: 0.3496
# [2026-02-01 17:53:50] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:53:50] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:53:50] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:53:50] [train_epoch] Using device: cuda
# [2026-02-01 17:55:28] [train_epoch] Epoch Loss: 2.8395 | Epoch Acc: 0.3894
# [2026-02-01 17:55:28] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:55:28] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:55:28] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:55:28] [validate] Using device: cuda
# [2026-02-01 17:56:16] [validate] Validation Loss: 2.8722 | Validation Acc: 0.3639
# [2026-02-01 17:56:16] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:56:16] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:56:16] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:56:16] [test_model] Using device: cuda
# [2026-02-01 17:57:05] [test_model] Test Loss: 2.8812 | Test Acc: 0.3481
# [2026-02-01 17:57:05] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 17:57:05] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 17:57:05] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:57:05] [train_epoch] Using device: cuda
# [2026-02-01 17:58:42] [train_epoch] Epoch Loss: 2.7180 | Epoch Acc: 0.4126
# [2026-02-01 17:58:42] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 17:58:42] [validate]                   Dataloader: DataLoader,
# [2026-02-01 17:58:42] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:58:42] [validate] Using device: cuda
# [2026-02-01 17:59:31] [validate] Validation Loss: 2.7697 | Validation Acc: 0.3937
# [2026-02-01 17:59:31] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 17:59:31] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 17:59:31] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 17:59:31] [test_model] Using device: cuda
# [2026-02-01 18:00:20] [test_model] Test Loss: 2.7783 | Test Acc: 0.3823
# [2026-02-01 18:00:20] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 18:00:20] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 18:00:20] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:00:20] [train_epoch] Using device: cuda
# [2026-02-01 18:01:57] [train_epoch] Epoch Loss: 2.6149 | Epoch Acc: 0.4404
# [2026-02-01 18:01:57] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 18:01:57] [validate]                   Dataloader: DataLoader,
# [2026-02-01 18:01:57] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:01:57] [validate] Using device: cuda
# [2026-02-01 18:02:46] [validate] Validation Loss: 2.6826 | Validation Acc: 0.4089
# [2026-02-01 18:02:46] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 18:02:46] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 18:02:46] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:02:46] [test_model] Using device: cuda
# [2026-02-01 18:03:35] [test_model] Test Loss: 2.6947 | Test Acc: 0.4160
# [2026-02-01 18:03:35] [train_epoch] Starting train on Model:     YOLOv5Classifier,
# [2026-02-01 18:03:35] [train_epoch]                   Optimizer: Adam,
# [2026-02-01 18:03:35] [train_epoch]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:03:35] [train_epoch] Using device: cuda
# [2026-02-01 18:05:12] [train_epoch] Epoch Loss: 2.5209 | Epoch Acc: 0.4541
# [2026-02-01 18:05:12] [validate] Starting validate on Model:     YOLOv5Classifier,
# [2026-02-01 18:05:12] [validate]                   Dataloader: DataLoader,
# [2026-02-01 18:05:12] [validate]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:05:12] [validate] Using device: cuda
# [2026-02-01 18:06:01] [validate] Validation Loss: 2.6073 | Validation Acc: 0.4240
# [2026-02-01 18:06:01] [test_model] Starting test on Model:     YOLOv5Classifier,
# [2026-02-01 18:06:01] [test_model]                   Dataloader: DataLoader,
# [2026-02-01 18:06:01] [test_model]                   Criterion: CrossEntropyLoss
# [2026-02-01 18:06:01] [test_model] Using device: cuda
# [2026-02-01 18:06:48] [test_model] Test Loss: 2.6190 | Test Acc: 0.4214

# %% [markdown]
# Save results to back to drive:

# %%
# !cp -r results/ '<path-to-results-on-drive>'
